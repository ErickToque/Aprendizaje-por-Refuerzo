# %% [markdown]
# # Q-Learning y Deep Learning (DQN)

# %% [markdown]
# Q-Learning y Deep Learning (DQN)
# Conceptos clave
# Q-Learning clásico: usa una tabla Q para almacenar valores Q(s,a). Esto funciona bien para espacios de estado pequeños y discretos.
#
# Deep Q-Network (DQN): usa una red neuronal para aproximar la función Q(s,a), permitiendo manejar espacios de estado grandes o continuos.
#
# La red recibe el estado como entrada y produce un valor Q para cada acción posible.
#
# Se entrena usando las muestras de experiencia (transiciones estado, acción, recompensa, siguiente estado).

# %%
pip install gymnasium[all]  # para instalar gymnasium con todos los extras
# Out:
# Requirement already satisfied: gymnasium[all] in /usr/local/lib/python3.11/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.11.2)
# Collecting box2d-py==2.3.5 (from gymnasium[all])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (2.6.1)
# Collecting swig==4.* (from gymnasium[all])
#   Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Collecting mujoco>=2.1.5 (from gymnasium[all])
#   Downloading mujoco-3.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (2.37.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (25.0)
# Requirement already satisfied: jax>=0.4.16 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.5.3)
# Requirement already satisfied: jaxlib>=0.4.16 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.5.3)
# Requirement already satisfied: flax>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (0.10.6)
# Collecting array-api-compat>=1.11.0 (from gymnasium[all])
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting numpy>=1.21.0 (from gymnasium[all])
#   Downloading numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (2.6.0+cu124)
# Requirement already satisfied: opencv-python>=3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (4.12.0.88)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (3.10.0)
# Requirement already satisfied: moviepy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[all]) (1.0.3)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (1.1.1)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.2.5)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.11.20)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.1.76)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.5.0->gymnasium[all]) (0.1.9)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio>=2.14.1->gymnasium[all]) (11.3.0)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.16->gymnasium[all]) (0.5.3)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.16->gymnasium[all]) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.16->gymnasium[all]) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->gymnasium[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->gymnasium[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->gymnasium[all]) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->gymnasium[all]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->gymnasium[all]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->gymnasium[all]) (2.9.0.post0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (0.1.12)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy>=1.0.0->gymnasium[all]) (0.6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (1.13.0)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[all])
#   Downloading glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.1.5->gymnasium[all]) (3.1.9)
# Collecting numpy>=1.21.0 (from gymnasium[all])
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->gymnasium[all]) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->gymnasium[all]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->gymnasium[all]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->gymnasium[all]) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->gymnasium[all]) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->gymnasium[all]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.13.0->gymnasium[all])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->gymnasium[all]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->gymnasium[all]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->gymnasium[all]) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[all]) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.19.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[all]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[all]) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->gymnasium[all]) (3.0.2)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.5.0->gymnasium[all]) (0.1.90)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (3.20.1)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.5.0->gymnasium[all]) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.0->gymnasium[all]) (0.1.2)
# Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.1 MB/s eta 0:00:00
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 4.0 MB/s eta 0:00:00
# Downloading mujoco-3.3.5-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 69.9 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 58.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 22.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.9 MB/s eta 0:00:00
# Downloading glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 15.6 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for box2d-py (setup.py) ... error
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (box2d-py)

# %%
import gymnasium as gym

env = gym.make("CartPole-v1")  # Crear el entorno
state, info = env.reset()       # Aquí sí devuelve dos valores

action = env.action_space.sample()  # Por ejemplo, una acción aleatoria

next_state, reward, terminated, truncated, info = env.step(action)
done = terminated or truncated

# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque

# Red neuronal para aproximar Q(s,a)
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, action_dim)
        )

    def forward(self, x):
        return self.net(x)

# Configuración
env = gym.make("CartPole-v1")
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

policy_net = DQN(state_dim, action_dim)
target_net = DQN(state_dim, action_dim)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=0.001)
criterion = nn.MSELoss()

memory = deque(maxlen=10000)
batch_size = 64
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.01
epsilon_decay = 0.995
num_episodes = 300
target_update = 10

def select_action(state):
    global epsilon
    if random.random() < epsilon:
        return env.action_space.sample()
    else:
        state_v = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = policy_net(state_v)
        return torch.argmax(q_values).item()

def optimize_model():
    if len(memory) < batch_size:
        return
    batch = random.sample(memory, batch_size)
    states, actions, rewards, next_states, dones = zip(*batch)

    states = torch.FloatTensor(states)
    actions = torch.LongTensor(actions).unsqueeze(1)
    rewards = torch.FloatTensor(rewards).unsqueeze(1)
    next_states = torch.FloatTensor(next_states)
    dones = torch.FloatTensor(dones).unsqueeze(1)

    q_values = policy_net(states).gather(1, actions)
    with torch.no_grad():
        max_next_q_values = target_net(next_states).max(1)[0].unsqueeze(1)
        target_q_values = rewards + gamma * max_next_q_values * (1 - dones)

    loss = criterion(q_values, target_q_values)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# Entrenamiento
for episode in range(num_episodes):
    state, _ = env.reset()  # <-- aquí el cambio
    done = False
    total_reward = 0

    while not done:
        action = select_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)  # <-- cambio aquí
        done = terminated or truncated

        memory.append((state, action, reward, next_state, float(done)))
        state = next_state
        total_reward += reward

        optimize_model()

    epsilon = max(epsilon_min, epsilon * epsilon_decay)

    if episode % target_update == 0:
        target_net.load_state_dict(policy_net.state_dict())

    print(f"Episodio {episode+1}, Recompensa: {total_reward}, Epsilon: {epsilon:.3f}")

env.close()
# Out:
# Episodio 1, Recompensa: 31.0, Epsilon: 0.995
# /tmp/ipython-input-1175945364.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   states = torch.FloatTensor(states)
# Episodio 2, Recompensa: 52.0, Epsilon: 0.990
# Episodio 3, Recompensa: 19.0, Epsilon: 0.985
# Episodio 4, Recompensa: 30.0, Epsilon: 0.980
# Episodio 5, Recompensa: 39.0, Epsilon: 0.975
# Episodio 6, Recompensa: 16.0, Epsilon: 0.970
# Episodio 7, Recompensa: 15.0, Epsilon: 0.966
# Episodio 8, Recompensa: 13.0, Epsilon: 0.961
# Episodio 9, Recompensa: 27.0, Epsilon: 0.956
# Episodio 10, Recompensa: 10.0, Epsilon: 0.951
# Episodio 11, Recompensa: 36.0, Epsilon: 0.946
# Episodio 12, Recompensa: 19.0, Epsilon: 0.942
# Episodio 13, Recompensa: 35.0, Epsilon: 0.937
# Episodio 14, Recompensa: 28.0, Epsilon: 0.932
# Episodio 15, Recompensa: 11.0, Epsilon: 0.928
# Episodio 16, Recompensa: 39.0, Epsilon: 0.923
# Episodio 17, Recompensa: 22.0, Epsilon: 0.918
# Episodio 18, Recompensa: 15.0, Epsilon: 0.914
# Episodio 19, Recompensa: 25.0, Epsilon: 0.909
# Episodio 20, Recompensa: 21.0, Epsilon: 0.905
# Episodio 21, Recompensa: 16.0, Epsilon: 0.900
# Episodio 22, Recompensa: 19.0, Epsilon: 0.896
# Episodio 23, Recompensa: 17.0, Epsilon: 0.891
# Episodio 24, Recompensa: 25.0, Epsilon: 0.887
# Episodio 25, Recompensa: 44.0, Epsilon: 0.882
# Episodio 26, Recompensa: 10.0, Epsilon: 0.878
# Episodio 27, Recompensa: 17.0, Epsilon: 0.873
# Episodio 28, Recompensa: 11.0, Epsilon: 0.869
# Episodio 29, Recompensa: 32.0, Epsilon: 0.865
# Episodio 30, Recompensa: 16.0, Epsilon: 0.860
# Episodio 31, Recompensa: 21.0, Epsilon: 0.856
# Episodio 32, Recompensa: 19.0, Epsilon: 0.852
# Episodio 33, Recompensa: 51.0, Epsilon: 0.848
# Episodio 34, Recompensa: 53.0, Epsilon: 0.843
# Episodio 35, Recompensa: 14.0, Epsilon: 0.839
# Episodio 36, Recompensa: 88.0, Epsilon: 0.835
# Episodio 37, Recompensa: 19.0, Epsilon: 0.831
# Episodio 38, Recompensa: 22.0, Epsilon: 0.827
# Episodio 39, Recompensa: 11.0, Epsilon: 0.822
# Episodio 40, Recompensa: 21.0, Epsilon: 0.818
# Episodio 41, Recompensa: 49.0, Epsilon: 0.814
# Episodio 42, Recompensa: 34.0, Epsilon: 0.810
# Episodio 43, Recompensa: 52.0, Epsilon: 0.806
# Episodio 44, Recompensa: 49.0, Epsilon: 0.802
# Episodio 45, Recompensa: 21.0, Epsilon: 0.798
# Episodio 46, Recompensa: 13.0, Epsilon: 0.794
# Episodio 47, Recompensa: 42.0, Epsilon: 0.790
# Episodio 48, Recompensa: 13.0, Epsilon: 0.786
# Episodio 49, Recompensa: 27.0, Epsilon: 0.782
# Episodio 50, Recompensa: 47.0, Epsilon: 0.778
# Episodio 51, Recompensa: 11.0, Epsilon: 0.774
# Episodio 52, Recompensa: 12.0, Epsilon: 0.771
# Episodio 53, Recompensa: 116.0, Epsilon: 0.767
# Episodio 54, Recompensa: 10.0, Epsilon: 0.763
# Episodio 55, Recompensa: 93.0, Epsilon: 0.759
# Episodio 56, Recompensa: 19.0, Epsilon: 0.755
# Episodio 57, Recompensa: 41.0, Epsilon: 0.751
# Episodio 58, Recompensa: 65.0, Epsilon: 0.748
# Episodio 59, Recompensa: 10.0, Epsilon: 0.744
# Episodio 60, Recompensa: 24.0, Epsilon: 0.740
# Episodio 61, Recompensa: 15.0, Epsilon: 0.737
# Episodio 62, Recompensa: 60.0, Epsilon: 0.733
# Episodio 63, Recompensa: 31.0, Epsilon: 0.729
# Episodio 64, Recompensa: 22.0, Epsilon: 0.726
# Episodio 65, Recompensa: 20.0, Epsilon: 0.722
# Episodio 66, Recompensa: 29.0, Epsilon: 0.718
# Episodio 67, Recompensa: 28.0, Epsilon: 0.715
# Episodio 68, Recompensa: 17.0, Epsilon: 0.711
# Episodio 69, Recompensa: 8.0, Epsilon: 0.708
# Episodio 70, Recompensa: 28.0, Epsilon: 0.704
# Episodio 71, Recompensa: 54.0, Epsilon: 0.701
# Episodio 72, Recompensa: 20.0, Epsilon: 0.697
# Episodio 73, Recompensa: 29.0, Epsilon: 0.694
# Episodio 74, Recompensa: 56.0, Epsilon: 0.690
# Episodio 75, Recompensa: 13.0, Epsilon: 0.687
# Episodio 76, Recompensa: 139.0, Epsilon: 0.683
# Episodio 77, Recompensa: 56.0, Epsilon: 0.680
# Episodio 78, Recompensa: 38.0, Epsilon: 0.676
# Episodio 79, Recompensa: 24.0, Epsilon: 0.673
# Episodio 80, Recompensa: 32.0, Epsilon: 0.670
# Episodio 81, Recompensa: 92.0, Epsilon: 0.666
# Episodio 82, Recompensa: 51.0, Epsilon: 0.663
# Episodio 83, Recompensa: 113.0, Epsilon: 0.660
# Episodio 84, Recompensa: 14.0, Epsilon: 0.656
# Episodio 85, Recompensa: 121.0, Epsilon: 0.653
# Episodio 86, Recompensa: 171.0, Epsilon: 0.650
# Episodio 87, Recompensa: 37.0, Epsilon: 0.647
# Episodio 88, Recompensa: 10.0, Epsilon: 0.643
# Episodio 89, Recompensa: 25.0, Epsilon: 0.640
# Episodio 90, Recompensa: 83.0, Epsilon: 0.637
# Episodio 91, Recompensa: 24.0, Epsilon: 0.634
# Episodio 92, Recompensa: 122.0, Epsilon: 0.631
# Episodio 93, Recompensa: 44.0, Epsilon: 0.627
# Episodio 94, Recompensa: 156.0, Epsilon: 0.624
# Episodio 95, Recompensa: 30.0, Epsilon: 0.621
# Episodio 96, Recompensa: 12.0, Epsilon: 0.618
# Episodio 97, Recompensa: 67.0, Epsilon: 0.615
# Episodio 98, Recompensa: 67.0, Epsilon: 0.612
# Episodio 99, Recompensa: 56.0, Epsilon: 0.609
# Episodio 100, Recompensa: 35.0, Epsilon: 0.606
# Episodio 101, Recompensa: 48.0, Epsilon: 0.603
# Episodio 102, Recompensa: 137.0, Epsilon: 0.600
# Episodio 103, Recompensa: 78.0, Epsilon: 0.597
# Episodio 104, Recompensa: 140.0, Epsilon: 0.594
# Episodio 105, Recompensa: 151.0, Epsilon: 0.591
# Episodio 106, Recompensa: 48.0, Epsilon: 0.588
# Episodio 107, Recompensa: 136.0, Epsilon: 0.585
# Episodio 108, Recompensa: 36.0, Epsilon: 0.582
# Episodio 109, Recompensa: 19.0, Epsilon: 0.579
# Episodio 110, Recompensa: 61.0, Epsilon: 0.576
# Episodio 111, Recompensa: 67.0, Epsilon: 0.573
# Episodio 112, Recompensa: 43.0, Epsilon: 0.570
# Episodio 113, Recompensa: 23.0, Epsilon: 0.568
# Episodio 114, Recompensa: 130.0, Epsilon: 0.565
# Episodio 115, Recompensa: 216.0, Epsilon: 0.562
# Episodio 116, Recompensa: 12.0, Epsilon: 0.559
# Episodio 117, Recompensa: 18.0, Epsilon: 0.556
# Episodio 118, Recompensa: 38.0, Epsilon: 0.554
# Episodio 119, Recompensa: 12.0, Epsilon: 0.551
# Episodio 120, Recompensa: 14.0, Epsilon: 0.548
# Episodio 121, Recompensa: 79.0, Epsilon: 0.545
# Episodio 122, Recompensa: 196.0, Epsilon: 0.543
# Episodio 123, Recompensa: 192.0, Epsilon: 0.540
# Episodio 124, Recompensa: 116.0, Epsilon: 0.537
# Episodio 125, Recompensa: 101.0, Epsilon: 0.534
# Episodio 126, Recompensa: 80.0, Epsilon: 0.532
# Episodio 127, Recompensa: 26.0, Epsilon: 0.529
# Episodio 128, Recompensa: 84.0, Epsilon: 0.526
# Episodio 129, Recompensa: 154.0, Epsilon: 0.524
# Episodio 130, Recompensa: 139.0, Epsilon: 0.521
# Episodio 131, Recompensa: 133.0, Epsilon: 0.519
# Episodio 132, Recompensa: 88.0, Epsilon: 0.516
# Episodio 133, Recompensa: 14.0, Epsilon: 0.513
# Episodio 134, Recompensa: 56.0, Epsilon: 0.511
# Episodio 135, Recompensa: 18.0, Epsilon: 0.508
# Episodio 136, Recompensa: 84.0, Epsilon: 0.506
# Episodio 137, Recompensa: 191.0, Epsilon: 0.503
# Episodio 138, Recompensa: 33.0, Epsilon: 0.501
# Episodio 139, Recompensa: 44.0, Epsilon: 0.498
# Episodio 140, Recompensa: 98.0, Epsilon: 0.496
# Episodio 141, Recompensa: 60.0, Epsilon: 0.493
# Episodio 142, Recompensa: 124.0, Epsilon: 0.491
# Episodio 143, Recompensa: 20.0, Epsilon: 0.488
# Episodio 144, Recompensa: 13.0, Epsilon: 0.486
# Episodio 145, Recompensa: 92.0, Epsilon: 0.483
# Episodio 146, Recompensa: 61.0, Epsilon: 0.481
# Episodio 147, Recompensa: 161.0, Epsilon: 0.479
# Episodio 148, Recompensa: 40.0, Epsilon: 0.476
# Episodio 149, Recompensa: 14.0, Epsilon: 0.474
# Episodio 150, Recompensa: 104.0, Epsilon: 0.471
# Episodio 151, Recompensa: 42.0, Epsilon: 0.469
# Episodio 152, Recompensa: 97.0, Epsilon: 0.467
# Episodio 153, Recompensa: 110.0, Epsilon: 0.464
# Episodio 154, Recompensa: 149.0, Epsilon: 0.462
# Episodio 155, Recompensa: 90.0, Epsilon: 0.460
# Episodio 156, Recompensa: 120.0, Epsilon: 0.458
# Episodio 157, Recompensa: 56.0, Epsilon: 0.455
# Episodio 158, Recompensa: 11.0, Epsilon: 0.453
# Episodio 159, Recompensa: 137.0, Epsilon: 0.451
# Episodio 160, Recompensa: 142.0, Epsilon: 0.448
# Episodio 161, Recompensa: 63.0, Epsilon: 0.446
# Episodio 162, Recompensa: 135.0, Epsilon: 0.444
# Episodio 163, Recompensa: 69.0, Epsilon: 0.442
# Episodio 164, Recompensa: 14.0, Epsilon: 0.440
# Episodio 165, Recompensa: 15.0, Epsilon: 0.437
# Episodio 166, Recompensa: 131.0, Epsilon: 0.435
# Episodio 167, Recompensa: 24.0, Epsilon: 0.433
# Episodio 168, Recompensa: 38.0, Epsilon: 0.431
# Episodio 169, Recompensa: 40.0, Epsilon: 0.429
# Episodio 170, Recompensa: 14.0, Epsilon: 0.427
# Episodio 171, Recompensa: 11.0, Epsilon: 0.424
# Episodio 172, Recompensa: 77.0, Epsilon: 0.422
# Episodio 173, Recompensa: 296.0, Epsilon: 0.420
# Episodio 174, Recompensa: 193.0, Epsilon: 0.418
# Episodio 175, Recompensa: 83.0, Epsilon: 0.416
# Episodio 176, Recompensa: 142.0, Epsilon: 0.414
# Episodio 177, Recompensa: 15.0, Epsilon: 0.412
# Episodio 178, Recompensa: 18.0, Epsilon: 0.410
# Episodio 179, Recompensa: 61.0, Epsilon: 0.408
# Episodio 180, Recompensa: 107.0, Epsilon: 0.406
# Episodio 181, Recompensa: 109.0, Epsilon: 0.404
# Episodio 182, Recompensa: 22.0, Epsilon: 0.402
# Episodio 183, Recompensa: 50.0, Epsilon: 0.400
# Episodio 184, Recompensa: 190.0, Epsilon: 0.398
# Episodio 185, Recompensa: 113.0, Epsilon: 0.396
# Episodio 186, Recompensa: 119.0, Epsilon: 0.394
# Episodio 187, Recompensa: 125.0, Epsilon: 0.392
# Episodio 188, Recompensa: 42.0, Epsilon: 0.390
# Episodio 189, Recompensa: 27.0, Epsilon: 0.388
# Episodio 190, Recompensa: 28.0, Epsilon: 0.386
# Episodio 191, Recompensa: 65.0, Epsilon: 0.384
# Episodio 192, Recompensa: 91.0, Epsilon: 0.382
# Episodio 193, Recompensa: 21.0, Epsilon: 0.380
# Episodio 194, Recompensa: 235.0, Epsilon: 0.378
# Episodio 195, Recompensa: 42.0, Epsilon: 0.376
# Episodio 196, Recompensa: 30.0, Epsilon: 0.374
# Episodio 197, Recompensa: 134.0, Epsilon: 0.373
# Episodio 198, Recompensa: 67.0, Epsilon: 0.371
# Episodio 199, Recompensa: 66.0, Epsilon: 0.369
# Episodio 200, Recompensa: 38.0, Epsilon: 0.367
# Episodio 201, Recompensa: 31.0, Epsilon: 0.365
# Episodio 202, Recompensa: 129.0, Epsilon: 0.363
# Episodio 203, Recompensa: 71.0, Epsilon: 0.361
# Episodio 204, Recompensa: 36.0, Epsilon: 0.360
# Episodio 205, Recompensa: 112.0, Epsilon: 0.358
# Episodio 206, Recompensa: 13.0, Epsilon: 0.356
# Episodio 207, Recompensa: 45.0, Epsilon: 0.354
# Episodio 208, Recompensa: 21.0, Epsilon: 0.353
# Episodio 209, Recompensa: 265.0, Epsilon: 0.351
# Episodio 210, Recompensa: 152.0, Epsilon: 0.349
# Episodio 211, Recompensa: 174.0, Epsilon: 0.347
# Episodio 212, Recompensa: 13.0, Epsilon: 0.346
# Episodio 213, Recompensa: 16.0, Epsilon: 0.344
# Episodio 214, Recompensa: 154.0, Epsilon: 0.342
# Episodio 215, Recompensa: 118.0, Epsilon: 0.340
# Episodio 216, Recompensa: 188.0, Epsilon: 0.339
# Episodio 217, Recompensa: 62.0, Epsilon: 0.337
# Episodio 218, Recompensa: 147.0, Epsilon: 0.335
# Episodio 219, Recompensa: 174.0, Epsilon: 0.334
# Episodio 220, Recompensa: 56.0, Epsilon: 0.332
# Episodio 221, Recompensa: 11.0, Epsilon: 0.330
# Episodio 222, Recompensa: 75.0, Epsilon: 0.329
# Episodio 223, Recompensa: 108.0, Epsilon: 0.327
# Episodio 224, Recompensa: 33.0, Epsilon: 0.325
# Episodio 225, Recompensa: 53.0, Epsilon: 0.324
# Episodio 226, Recompensa: 86.0, Epsilon: 0.322
# Episodio 227, Recompensa: 118.0, Epsilon: 0.321
# Episodio 228, Recompensa: 73.0, Epsilon: 0.319
# Episodio 229, Recompensa: 179.0, Epsilon: 0.317
# Episodio 230, Recompensa: 79.0, Epsilon: 0.316
# Episodio 231, Recompensa: 105.0, Epsilon: 0.314
# Episodio 232, Recompensa: 42.0, Epsilon: 0.313
# Episodio 233, Recompensa: 68.0, Epsilon: 0.311
# Episodio 234, Recompensa: 97.0, Epsilon: 0.309
# Episodio 235, Recompensa: 100.0, Epsilon: 0.308
# Episodio 236, Recompensa: 24.0, Epsilon: 0.306
# Episodio 237, Recompensa: 46.0, Epsilon: 0.305
# Episodio 238, Recompensa: 91.0, Epsilon: 0.303
# Episodio 239, Recompensa: 116.0, Epsilon: 0.302
# Episodio 240, Recompensa: 15.0, Epsilon: 0.300
# Episodio 241, Recompensa: 99.0, Epsilon: 0.299
# Episodio 242, Recompensa: 92.0, Epsilon: 0.297
# Episodio 243, Recompensa: 107.0, Epsilon: 0.296
# Episodio 244, Recompensa: 36.0, Epsilon: 0.294
# Episodio 245, Recompensa: 129.0, Epsilon: 0.293
# Episodio 246, Recompensa: 19.0, Epsilon: 0.291
# Episodio 247, Recompensa: 139.0, Epsilon: 0.290
# Episodio 248, Recompensa: 132.0, Epsilon: 0.288
# Episodio 249, Recompensa: 57.0, Epsilon: 0.287
# Episodio 250, Recompensa: 12.0, Epsilon: 0.286
# Episodio 251, Recompensa: 119.0, Epsilon: 0.284
# Episodio 252, Recompensa: 120.0, Epsilon: 0.283
# Episodio 253, Recompensa: 181.0, Epsilon: 0.281
# Episodio 254, Recompensa: 128.0, Epsilon: 0.280
# Episodio 255, Recompensa: 116.0, Epsilon: 0.279
# Episodio 256, Recompensa: 27.0, Epsilon: 0.277
# Episodio 257, Recompensa: 88.0, Epsilon: 0.276
# Episodio 258, Recompensa: 96.0, Epsilon: 0.274
# Episodio 259, Recompensa: 150.0, Epsilon: 0.273
# Episodio 260, Recompensa: 171.0, Epsilon: 0.272
# Episodio 261, Recompensa: 141.0, Epsilon: 0.270
# Episodio 262, Recompensa: 139.0, Epsilon: 0.269
# Episodio 263, Recompensa: 253.0, Epsilon: 0.268
# Episodio 264, Recompensa: 118.0, Epsilon: 0.266
# Episodio 265, Recompensa: 116.0, Epsilon: 0.265
# Episodio 266, Recompensa: 202.0, Epsilon: 0.264
# Episodio 267, Recompensa: 123.0, Epsilon: 0.262
# Episodio 268, Recompensa: 93.0, Epsilon: 0.261
# Episodio 269, Recompensa: 180.0, Epsilon: 0.260
# Episodio 270, Recompensa: 125.0, Epsilon: 0.258
# Episodio 271, Recompensa: 152.0, Epsilon: 0.257
# Episodio 272, Recompensa: 55.0, Epsilon: 0.256
# Episodio 273, Recompensa: 179.0, Epsilon: 0.255
# Episodio 274, Recompensa: 189.0, Epsilon: 0.253
# Episodio 275, Recompensa: 165.0, Epsilon: 0.252
# Episodio 276, Recompensa: 376.0, Epsilon: 0.251
# Episodio 277, Recompensa: 34.0, Epsilon: 0.249
# Episodio 278, Recompensa: 20.0, Epsilon: 0.248
# Episodio 279, Recompensa: 179.0, Epsilon: 0.247
# Episodio 280, Recompensa: 69.0, Epsilon: 0.246
# Episodio 281, Recompensa: 47.0, Epsilon: 0.245
# Episodio 282, Recompensa: 357.0, Epsilon: 0.243
# Episodio 283, Recompensa: 142.0, Epsilon: 0.242
# Episodio 284, Recompensa: 32.0, Epsilon: 0.241
# Episodio 285, Recompensa: 135.0, Epsilon: 0.240
# Episodio 286, Recompensa: 170.0, Epsilon: 0.238
# Episodio 287, Recompensa: 166.0, Epsilon: 0.237
# Episodio 288, Recompensa: 245.0, Epsilon: 0.236
# Episodio 289, Recompensa: 132.0, Epsilon: 0.235
# Episodio 290, Recompensa: 500.0, Epsilon: 0.234
# Episodio 291, Recompensa: 151.0, Epsilon: 0.233
# Episodio 292, Recompensa: 247.0, Epsilon: 0.231
# Episodio 293, Recompensa: 39.0, Epsilon: 0.230
# Episodio 294, Recompensa: 360.0, Epsilon: 0.229
# Episodio 295, Recompensa: 194.0, Epsilon: 0.228
# Episodio 296, Recompensa: 500.0, Epsilon: 0.227
# Episodio 297, Recompensa: 62.0, Epsilon: 0.226
# Episodio 298, Recompensa: 233.0, Epsilon: 0.225
# Episodio 299, Recompensa: 221.0, Epsilon: 0.223
# Episodio 300, Recompensa: 210.0, Epsilon: 0.222

# %%
state, _ = env.reset()
done = False
total_reward
# Out:
# 210.0

# %%
state, _ = env.reset()
done = False
total_reward = 0

while not done:
    state_v = torch.FloatTensor(state).unsqueeze(0)
    with torch.no_grad():
        q_values = policy_net(state_v)
    action = torch.argmax(q_values).item()
    next_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    state = next_state
    total_reward += reward
    env.render()

print(f"Recompensa en evaluación: {total_reward}")

env.close()
# Out:
# Recompensa en evaluación: 258.0
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/classic_control/cartpole.py:250: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(

# %%
torch.save(policy_net.state_dict(), "dqn_cartpole.pth")

# %%
num_eval_episodes = 10
total_rewards = []

for _ in range(num_eval_episodes):
    state, _ = env.reset()
    done = False
    episode_reward = 0
    while not done:
        state_v = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = policy_net(state_v)
        action = torch.argmax(q_values).item()
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        state = next_state
        episode_reward += reward
    total_rewards.append(episode_reward)

print(f"Recompensa promedio en {num_eval_episodes} episodios: {np.mean(total_rewards)}")
# Out:
# Recompensa promedio en 10 episodios: 248.6

# %%
import matplotlib.pyplot as plt
from gym.wrappers.monitoring import video_recorder

env = gym.make("CartPole-v1", render_mode="rgb_array")
recorder = video_recorder.VideoRecorder(env, path="cartpole_dqn.mp4")

state, _ = env.reset()
done = False

while not done:
    recorder.capture_frame()
    state_v = torch.FloatTensor(state).unsqueeze(0)
    with torch.no_grad():
        q_values = policy_net(state_v)
    action = torch.argmax(q_values).item()
    next_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    state = next_state

recorder.close()
env.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/monitoring/video_recorder.py:101: DeprecationWarning: WARN: <class 'gym.wrappers.monitoring.video_recorder.VideoRecorder'> is marked as deprecated and will be removed in the future.
#   logger.deprecation(
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)

# %%
# Guardar
torch.save(policy_net.state_dict(), "dqn_cartpole.pth")

# Cargar
policy_net.load_state_dict(torch.load("dqn_cartpole.pth"))
policy_net.eval()
# Out:
# DQN(
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
